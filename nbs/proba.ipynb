# %%
import pickle

# %%
with open('../outputs/ZTF_rr_periods_dict.pkl', 'rb') as f:
    proba = pickle.load(f)

# %%
proba
# Out:
# {4898: [0.5570232728489015, 93],
#  5523: [0.6433117903487847, 1535],
#  5921: [0.530769380343952, 1541],
#  6749: [0.674729387150575, 1560],
#  6852: [0.313881347754221, 1632],
#  124: [0.5585177597048724, 95],
#  260: [0.4738204225051577, 92],
#  1081: [0.532920543140231, 1645],
#  1202: [0.33567428955105433, 1648],
#  1254: [0.47079658698676935, 1659],
#  1884: [0.6091946888939831, 1529],
#  2011: [0.512752907645681, 2875],
#  2075: [0.3396335339718802, 146],
#  2352: [0.4583044003004407, 2870],
#  2396: [0.33404345017330217, 1523],
#  2783: [0.6474464117442299, 1397],
#  3687: [0.5721599934443383, 1226],
#  4771: [0.8030073422364824, 1025],
#  4788: [0.5582299315175333, 1376],
#  4912: [0.492161909581361, 1737],
#  4928: [0.5957960271199607, 99],
#  5086: [0.521383035615104, 322],
#  5203: [0.5300398916830626, 1069],
#  5280: [0.7001111116258049, 1234],
#  5285: [0.5352112256225724, 2655],
#  5338: [0.6992157952006619, 1139],
#  5344: [0.70924613128076, 1237],
# ...
